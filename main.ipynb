# %%
import torch 
import matplotlib.pyplot as plt
import random
import numpy as np

# %%
loaded = torch.load("dataset/eeg_5_95_std.pth")
data =  [loaded['dataset'][i] for i in range(len(loaded['dataset']) ) if loaded['dataset'][i]['subject'] == 1]

# %%
data_ = loaded['dataset']
labels = loaded['labels']
images = loaded['images']
size = len(data)

# %%
print(size)
# Out:
# 1985

# %%
i = random.randint(0, size)
eeg = data_[i]['eeg'].float().t()
eeg = eeg[20:460,:]
plt.imshow(eeg, aspect='auto', cmap='jet')
print(eeg.shape)
# Out:
# torch.Size([440, 128])

# %%
j = random.randint(0, 440)
plt.plot(eeg[j])

# %%
eeg.t().view(1,128,440)
# Out:
# tensor([[[ 0.4517,  0.4835,  0.4996,  ..., -0.5601, -0.5942, -0.6221],
#          [ 0.4266,  0.4320,  0.4070,  ..., -0.3345, -0.3391, -0.3281],
#          [ 0.2135,  0.3435,  0.4862,  ..., -0.4183, -0.3805, -0.3452],
#          ...,
#          [ 0.2634,  0.3376,  0.3401,  ...,  0.0349,  0.1707,  0.3113],
#          [ 0.0064,  0.0113,  0.0113,  ..., -0.0103, -0.0029,  0.0057],
#          [ 0.1459,  0.1994,  0.1860,  ..., -0.0846, -0.0065,  0.0877]]])

# %%
label = data_[i]['label']
label
# Out:
# 29

# %%
images[0]
# Out:
# 'n02951358_31190'

# %%
loaded2 = torch.load("dataset/eeg_55_95_std.pth")
data2 = [loaded2['dataset'][i] for i in range(
    len(loaded2['dataset'])) if loaded2['dataset'][i]['subject'] == 1]

# %%
data_2 = loaded2['dataset']
labels2 = loaded2['labels']
images2 = loaded2['images']
size2 = len(data2)
print(size2)
# Out:
# 1985
